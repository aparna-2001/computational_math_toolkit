# %% [markdown]
# <a href="https://colab.research.google.com/github/aparna-2001/computational_math_toolkit/blob/main/calculus_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#function

def square(x):
  print(x*x)

# %%
#work with this function

square(2)
# Out:
# 4

# %%
#Write a function for absolute value ∣x∣ without using abs()

def absolute(x):
  if x<0:
    return -x
  else:
    return x

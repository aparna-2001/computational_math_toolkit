# %% [markdown]
# <a href="https://colab.research.google.com/github/aparna-2001/computational_math_toolkit/blob/main/BasicStat_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#correlation coefficient


def find_corr_x_y(x, y):
    n = len(x)

    if n!=len(y):
      return "Data invalid"
    else:
      prod = []
      for xi, yi in zip(x, y):
          prod.append(xi * yi)

      sum_prod_x_y = sum(prod)
      sum_x = sum(x)
      sum_y = sum(y)
      squared_sum_x = sum_x**2
      squared_sum_y = sum_y**2

      x_square = []
      for xi in x:
          x_square.append(xi**2)
      x_square_sum = sum(x_square)

      y_square = []
      for yi in y:
          y_square.append(yi**2)
      y_square_sum = sum(y_square)

      numerator = n * sum_prod_x_y - sum_x * sum_y
      denominator_term1 = n * x_square_sum - squared_sum_x
      denominator_term2 = n * y_square_sum - squared_sum_y
      denominator = (denominator_term1 * denominator_term2) ** 0.5

      correlation_coefficient = numerator / denominator
      return correlation_coefficient


x = [1,2,3,4]
y = [2,6,8]



find_corr_x_y(x,y)
# Out:
# 'Data invalid'

# %%
#creating my own csv data

import csv

data_file = [["x","y"], [1,2],[3,4],[5,6],[7,8]]

with open("data_file.csv", "w") as file:
    writer = csv.writer(file)
    writer.writerows(data_file)



import pandas as pd

df = pd.read_csv("data_file.csv")
print(df)
# Out:
#    x  y
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %%
with open("x,y.csv", "w") as file:
    #writer = csv.writer(file)
    #writer.writerows(data_file)


import pandas as pd

df = pd.read_csv("data_file.csv")
print(df)
# Out:
#    x  y
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

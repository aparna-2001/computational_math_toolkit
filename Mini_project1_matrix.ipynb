# %% [markdown]
# <a href="https://colab.research.google.com/github/aparna-2001/computational_math_toolkit/blob/main/Mini_project1_matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Matrix calculator**
#
# - take the data from any source
#
# - convert it to matrix (if needed first table to then matrix)
#
# -find the order
#
# -if order m = n
#
# - find the determinant - inference
#
# - find the inverse - inference
#
# - find the eigen values and eigen vector - inference
#
# - find the rank

# %%
#input of data

import numpy as np
import pandas as pd

rows = int(input("Enter the number of rows:"))
cols = int(input("Enter the number of columns:"))

matrix = []

for i in range(rows):
  row = list(map(int,input(f"Enter row{i + 1}: ").split(',')))
  matrix.append(row)

matrix_1 = np.array(matrix)
print(matrix_1)

print(matrix_1.shape)

def det_matrix(matrix_1):
         matrix_1_det = np.linalg.det(matrix_1)
         print(matrix_1_det)

if matrix_1.shape[0]==matrix_1.shape[1]:
   det_matrix(matrix_1)
else:
  print("The matrix is not a square matrix")

if (matrix_1_det!=0):
# Out:
#   File "/tmp/ipython-input-302224073.py", line 30
#
#     ^
# SyntaxError: incomplete input

# %%
# finding the determinant

import numpy as np

def det_matrix():
    try:
      matrix_1 = np.linalg.det(matrix_1)
      print(matrix_1)
    except:
      print("This is a non square matrix")

# %%
#finding the inverse

def inverse_matrix():
  try:
    matrix_inv = np.linalg.inv(matrix_1)
    print(matrix_inv)
  except:
    print('The matrix is singular or The matrix is not square matrix')

# %%
#finding the eigen values and eigen vectors

def eigen_matrix():
  try:
    Eigen_values,Eigen_vectors = np.linalg.eig(matrix_1)
    print(Eigen_values)
    print(Eigen_vectors)
  except:
    print('The matrix is not a square matrix')

# %%
#finding the rank

def rank_matrix():
    rank = np.linalg.matrix_rank(matrix_1)
    print(rank)
